# %% [markdown]
# # DYNAMICAL SYSTEMS

# %% [markdown]
# * All the ways of thinking about causation have been reduced to one notion
#   *  Effective or Efficient Causation
#      * One failure stikes another and keeps going on.
#      * There is an event that precedes another event, where the dependent variable affects the independent variable
#      * A→ B → C
# * Explanation of the “cause”
#   * C is caused by B
#   * But what causes A??
#     * It is not god
#     * It is a linear model, which is great
#       * Prevents circular explanation
# * Kant focuses on the biological understandings which aristotle was good at
#   * He sees a tree. Where does the tree gets his energy for its leaves?
#   * The sun; Self organising
#   * Tracing the lines of explanation of the above(circular causation), Circulatory explanation is not a cause of science living thing
#   * If the system is circulatory, explaining it will lead us outside of the scientific world
#   * The above argument is technically valid, but the argument as a whole is incomplete
#   * Dynamic Systems allows us to trace out circular causation without falling into circular explanation
#   * We don’t want to lose the formal causation by Aristotle
#   * This way, Kant’s premises must change unless biology isn’t a science

# %% [markdown]
# ### One-line Summary:
# The way how dynamical systems work is through effective/efficient causation. One cuses another and keeps going on, where independent and dependent variables are present. For example, envuronments, the sun are self organising. Through circulatory causation, we will be able to avoid circulatory explanation.

# %% [markdown]
# * Juerrero
#  * Looking at events, not looking at the conditions
#      * Causes → events(changes in actuality) → change in actuality
#      * Constraints → condition → Changes in possibility of an event’
#  * Potential ←→ Actuality = reality…
#      * Is Potentiality real? No because it is a contrast
#      * Conservation of energy not real if we lose energy???
#      * F = ma
#          * Is this an event???
#          * Where does this happen?
#          * It is a statement of condition, not an even
#  * Both the cause and constraints are real
#      * This is why rational thinkers are stupid because they don’t understand the complexity of scientific explanation
#  * Events cause a structural functional organisation → provides constraints the events(shapes the possibility of further events happening)
#      * Not a circular explanation because two different metaphysical notions are used → Cause, Constraint
#      * Complex causal feedback pathways that cause a structural functional organisations that shifts the probability of events occuring
#      * How tall is she?
#          * Does not necessarily mean she is tall?
#      * How short is she
#          * She is short
#  * Constraint → we must hear it like tall, rather short
#      * Enabling constraints increase the possibilities of a system
#  * Darwin’s theory of evolution by natural selection
#      * Explanation of evolution by natural selection
#      * We need a biological system that does Feedback process
#          * Goats make more goats → Reproduction(this is the feedback system)
#          * No reproduction → No reproduction
#              * Two Constraints
#                  * Scarcity
#                      * Puts selective pressure on organisms, not all organisms could survive
#                      * Reduces the options available for life
#                      * Scarcity → Environment kills off forms of life
#                  * Variation
#                      * Provides new options
#              * This is a feedback system
#                  * Variation provides, Selection kills, and repeat
#                      * The system revolves with change, with self-organisation
#      * Honesty
#          * If you ask me X, I will tell you the truth of X
#          * Selective constraints limit the possibilities
#      * Virtual world
#          * Virtual world needs virtual governings that need virtual generators
#          * Come up with a Virtual Engine that regulates selective and enabling constraints(regulates revolution)
#              * Explains how new morphological forms come to existence
#              * Natural selection on natural variation reaches here

# %% [markdown]
# ###  Summary of Juerrero:
# As the comp func and id theory failed, juerrero goes through kant's work to explain alternative solutions which mainly concern the buildings of a virtual machine.
#
# Juerrero review's Kant's work in terms of causation, and concludes that our explanations tend to be flawed due to the origin of the causation. For example, A leaf come to be a tree. But a tree becomes to be a...tree, which is circular. Rather than this, he suggested that these systems were dynamical systems, where constraints were put in terms of probabilities of events occuring(which is self organising).
#
# Some constraints increase/decrease the probability of happening. A good example is explanation of natural selection. This does a feedback process. By Scarcity, it puts selective pressure on organisms and results in the inferior ones to deterioriate. However, genetic variation allows various more organisms to evolve.
#
# So, juerrero suggests that selective constraits are virtual governors, and enabling constraits are virtual generators., which creates a feedback system. Therefore, we are able to retrieve intelligence from non-intelligent materials by the avoidance of circular explanation(homoncular fashion), through this type of dynamical system. This ends the homonuclar fallacy that the other theories had.

# %% [markdown]
#  ### Now we move onto the relevance problem.

# %% [markdown]
# * Does relevance have systematic import?
#     * We cannot have science of white things
#         * Not stable, not intrinsic
#         * Do they form a classical essence? no.
#         * A virtual engine that explains fittendess that temporarily redefines with the previous states of fitness is needed
#     * RR → X → RR
#         * Representational Level
#             * Representing the environment
#             * Seril
#                 * Representation is aspectual
#                     * Ex) Calling something w water bottle does not define every feature of that object
#                 * What is an aspect
#                     * Having a particular point of view on an object
#                     * Point of view in...Consciousness
#                         * Having a conscious experience
#                     * Representation depends on consciousness
#                         * Computational machines do not have consciousness, which therefore cannot have representation
#                     * Unconscious representation IS POSSIBLE, HOWEVER.
#                         * We subconsciously speak the rules of grammar when speaking a language without even realising them
#                         * Throws all the cognitive psychology argument out the window
#             * Vervaeke Response
#                 * Out of all the relatives(subset of all the relatives), what does aspectuality depend on?
#                 * We need to do relevance realisation
#                 * Relevance realisation is self-semantic
#             * Computation
#                 * Proposition of a certain syntactic structure
#                 * Combinatoric Explosion
#                 * Only select a subset you are going to use
#             * Making an inference
#                 * Implication → relationship  between propositions
#                 * Inference -> implications you select for what you want to believe(alter what you want to do)
#             * Capturing Rules
#                 * Problem with rules
#                 * Condition of Application
#                 * Each rules with condition of application
#                     * Infinitely spanders
#                         * Cannot capture rules in terms of rules
#                         * We cannot legislate everything we want in society
#                     * Computation presupposes relevance realisation

# %% [markdown]
# ## John Searl
# According to John Searl's point of view,, we do relevance realisation from the representations of aspects.
# We create aspects by a particular point of view, which means we cannot create representation without consciousness, as representation depends on it. Computational machines do not have consciousness and therefore cannot have representations, and unconscious represenation is possible but we subconsciously speak a language with gramatical rules without realisation. Consequently, the consciousness problem arises to the relevance problem, not giving us the answer.
#
# John Vervaeke adds on that since RR depends on aspectuality, you cannot have it. sub-semantic
# that is important - that relevance realisation is sub-semantic
# so then we drop this argument and instead look at our capacity for making inferences to possibly derive more principles of relevance realisation
#
# So we make inferences by taking a proposition and taking all its implications (of which there are a combinatorially explosive amount). Therefore we must select a subset of all these implications based on the context - so we use Relevance Realisation

# %% [markdown]
# * Bioeconomic Level
#     * Not regarding truth or falsity(this is semantic), not valid vs invalid(syntactic)
#     * Regards logistical values
#         * Optimal organisation of resources you have
#         * Organising equal amount of resources
#         * Ex) Distribution of Efficiency, Resiliency
#     * Darwin → Reproduction → Variation
#         * This is a Bioeconomic theory
#         * Each sensory motor loop moves to another sensory motor loop
#     * Reverse Engineering
#         * Shifting through large amount of information
#         * Differentiate things in different contexts
#         * No algorithmic rule for deciding things
#             * Evolve the fittedness with the optimal with generalising and discriminating
#         * Open up variation
#             * Tolerate “this” and “that”
#         * Evolve the networks to track the things it needs to track(virtual engine making)
#             * No over-generalising, or over-discriminating
#         * How do you balance between generalisation and discrimination? (general purpose machine vs special purpose machine? how to search through the environment?)
#             * Trade between Exploring and Exploiting
#         * Exploitation is a limiting strategy
#             * No subjecting yourself in movement or chain,very efficient when exploiting
#             * You have resiliency(miss relevant differences in the current context)
#         * Synchronicity ←→ Asynchronicity
#             * Self organising criticality
#                 * Organises → Avalanches → reorganises(repeat)
#                 * Brain compresses and open up
#                 * To fabricate General intelligence
#             * Brain implements Relevance realisation to do compression and particularisation(this is one way)
#                 * FInd immeasurable relations(found)
#                 * 2012 → 2013(vvk, ferrero)
#                     * Generally, brains are more flexible with SOC
#                     * Hesse and cross(2014) this is a plausible things to say
#                 * Brain oscillates of Synchronicity ←→ Asynchronicity, to achieve the above

# %% [markdown]
# # Bioeconomic Theory
# Now we make a virtual engine called bioeconomic theory uses logistical norms as well as efficiency and residency in order to function so in turn there is an analogy to derive here which is a bioeconomic system that varies between selection and variation to create a cycle of reproduction.
#
# This bioeconomic systes  we just made is another one of those virtual engines where the enablingconstraints are selection and the enabling constraints are reproduction.
#
# To do this lets go back to Geoffrey Hinton's wake sleep algorithm that varies between compression (selective constraints) and particularisation (enabling constraints) which helps the system both generalise and particularise to become more efficient and more resilient but what if we suggest that we can identify relevance as the ideal balance between this process of generalising and particularising?

# %% [markdown]
# * We don't need measurement of intelligence anymore. Now we just need to look at how well the brain is doing optimisation
# * Small world networks optimise efficiency and resiliency
#     * This is what general intelligence is
#     * This is how to measure the brain’s intelligence
# * Efficient hubs in the intelligence brain - article
#     * Brain is organised into small world networks
# * Exploitation → Explanation
#     * Both could be explained together in terms of meta constraints
#     * Both could be understood in terms of bioeconomics of efficiency and resilience
# * Vervaeke  - Problems
#     * Kolchinsky and Wolpert 2018
#     * How we go from the shannon information → pirelu formal syntactic to the semantic information
#     * Semantic information i syntactic information that a physical system has about its environment which is causally necessary for the system to maintain itself
#     * P(A|B) > P(A)
#         * There is a conditional relationship
#         * Causally necessarily for the system to maintain itself
#         * System that maintains itself → self organising system
#             * Not enough, self organisation does not mean it maintains
#             * Tornadoes are self organising but the toronado of gods do not create it
#             * Autopoetic
#     * Environment shifts and is subjected to change every time, so rather than using a constant autopoietic system, we need an adaptive autopoietic system
#         * Self organisation of relevance is needed
#         * Relevance realisation is realising what is relevant to an autopoietic system
#             * Pattern is a conditional probability that i can use to find the relevance realisation, so i can get the process of adaptive autopoietic system(which finds the original meaning of the system)
#     * Function of Consciousness
#         * Global world space
#             * The files are unconscious processes. You access the files(this is what consciousness does)
#             * We take what we have done and we broadcast it back to the files i want it to be in.
#         * Working memory(desktop, bring the files in) → manipulating information → broadcast it back
#             * Relevance realisation
#             * Shanahan(this is to solve the frame problem in relevance realisation)
#         * Working memory → Chunking of relevant information
#             * The more relevant realisation, the more relevant information we receive
#             * This is about general intelligence
#             * Increases likelihood of making the machine conscious
#         * Integrated information theory -- Tommi
#             * Why is your brain doing such integration?
#             * Removes important differences
#             * How to test a system is doing integration and differentiation of information?
#             * The test of conscious tests relevance realisation
#             * ***not all relevance realisation is conscious***
#                 * However, it does order consciousness
#             * Create a field of obviousness
#                 * Makes things salient to make things are particular to you(obvious)
#                 * Constantly evolving
#             * Frames → Figuration → forgrounding → featurisation
#             * Features of consciousness
#                 * Aspectualisaing
#                 * Centerity
#                 * Temporality
#             * Qualia
#                 * We don’t divide them up
#                 * Aggrevial VS adjectival
#                 * Adjectival is not necessary or enoug for consciousness because it could happen without it.

# %% [markdown]
# # Third Virtual Engine to the End
# So now, we have a new virtual engine that goes between exploitation and exploration (which Piaget dubs assimilation and accommodation).
# We can then conclude that compression is the same as particularisation which is the same as exploitation which is the same as assimilation - roughly.
# we also have evidence from neuroscience appears to do this when firing where it goes between synchrony and asynchrony
# what we can derive from this is evidence for self organising criticality and this is where the vervaeke and Ferrero (2013) study comes in. They suggest that general intelligence is RR because of self organising criticality
# so essentially they propose that we can measure how intelligent a system (such as brains or our networks we are trying to develop) is by how they optimise between efficiency and resiliency by self organising into small world networks.
# This is something that has been further proved and supported by Thatalor et al 2012, and by Hasse and Gross 2014 to be a very plausible explanation for the criterion of the cognitive
#
# This provides us with a plausible dynamical systems theory of how relevance realisation occurs in terms of a virtual engine that regulates the sensimotor loop so that is constantly evolving its fittedness to the environment
# using these we can also provide a final conclusion to original meaning.
# This comes from kolehinksy and walport in 2018.
# They suggest semantic information is syntactic information that a physical system has about its environment which is causally necessary for the system to maintain itself and for this to work we require a system that is adaptive auto poetic so then we can conclude from this that you can derive original meaning by linking RR and adaptive auto-poetic systems.
#
# Essentially we can use any syntactic information (any formal information or patterns between events) and through a process of RR zero in on it, so that we can incorporate it into our sensimotor loop so that we can solve our problems and achieve our goals, then it becomes original meaning.
#
# So by solving the relevance realisiation problem, we then effectively solve the original meaning problem
#
# However we are still left with the consciousness problem.
#
# One is the function of consciousness and the other is the nature of consciousness.
#
# One is the function of consciousness and the other is the nature of consciousness ---- we can find a plausible answer to the function of consciousness problem for Baars and his global work space theory.
#
# This is not done however. Consciousness makes things salient to you (to make a field of obviousness to you - by a process of OBVIATION ( to make things obvious to anticipate and avoid bad situations)) in a particular way to you, in order to make things obvious to you - you have to learn it and it is constantly evolving.
#
# So lets make another virtual engine to explain this process of obviation (which is also the nature of consciousness).
# We can root out virtual engine in something called sizing up.
# (sizing up is a process by which we identify features of something (like the idiom whereby we size something up).
#
# So what we have is a process of featurisation where some features are foregrounding, some are backgrounding, some features are figured (configured or otherwise), and there is a background of unified things that eventually fade off into a background non-unified things. On top of that there is framing which can frame particular problems form these features
#
# Using this we can then derive a a dynamically self organising process that is being constantly being done to create a perpetually salient landscape (it is doing obviation by featuring, foregrounding, figuration, and framing).
#
# But you could argue that there are situation where things are not salient, in which case the standard answer is we solve these problems via intuition, which is also something that can be explained by self organising criticality so we have a derived a distinct answer to the function of consciousness.
#
# What we have left is the distinct nature of consciousnes.
# We can derive this by arguing that there are two different features of consciousness - namely adverbial and adjectival. Adjectival features are not necessary nor sufficient for consciousness (see the pure consciousness event for an example) so then we are left with adverbial features of which there are three: Aspectuality - togetherness, Centravity - hereness, Temporality - nowness.

# %% [markdown]
# ### Closing Statement
# Now that we are theoretically resolve all the homuncularities and missing conditions, we may now theoretically argue that given the satisfiction of the above, we maybe able to re-create AI. However, as soon as this happens, what is special about us, such the characteristic that we satisfy all these theoretical problems, may not be unique and special to us anymore.
